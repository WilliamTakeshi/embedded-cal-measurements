# %%
import pandas as pd

# %%
def extract_edges(df):
    pairs = []
    start = None
    for t, v in zip(df["Timestamp"], df["Value"]):
        if v == 1 and start is None:
            start = t
        elif v == 0 and start is not None:
            pairs.append((start, t))
            start = None
    return pairs


def range_stats(edge, df2):
    start, end = edge
    window = df2[(df2["Timestamp"] >= start) & (df2["Timestamp"] <= end)]
    return {
        "max": window["Value"].max(),
        "avg": window["Value"].mean(),
        "min": window["Value"].min(),
    }

# %%
# experiment = "nrf_cracen_ec_mult_release"
# experiment = "nrf_cracen_aes_ecb_release"
# experiment = "nrf_cracen_sha256_release"
# experiment = "nrf_cracen_ecdsa_release"
# experiment = "nrf_rustcrypto_aes_ecb_release"
# experiment = "nrf_rustcrypto_sha256_release"
# experiment = "nrf_rustcrypto_ec_mult_release"
# experiment = "nrf_rustcrypto_ecdsa_release"
experiment = "stm_pac_aes_ecb_release"
# experiment = "stm_pac_sha256_release"
# experiment = "stm_pac_ecc_mult_release"
# experiment = "stm_pac_ecdsa_release"
# experiment = "stm_rustcrypto_ec_mult_release"
# experiment = "stm_rustcrypto_aes_ecm_release"
# experiment = "stm_rustcrypto_sha256_release"
# experiment = "stm_rustcrypto_ecdsa_release"


gpi1 = pd.read_csv(f"raw_measurements/{experiment}/GPI 1 - Ace.csv")
current = pd.read_csv(f"raw_measurements/{experiment}/Main current - Ace.csv")
power = pd.read_csv(f"raw_measurements/{experiment}/Main power - Ace.csv")

edges = extract_edges(gpi1)

# %%
for edge in edges:
    cur = range_stats(edge, current)
    pwr = range_stats(edge, power)
    
    print(
        f"{(edge[1] - edge[0]):.6f}, "
        f"{cur['avg']}, {cur['max']}, {cur['min']}, "
        f"{pwr['avg']}, {pwr['max']}, {pwr['min']}"
    )
# Out:
# 0.000020, 0.015218401749999999, 0.0153580261, 0.0150787774, 0.04550164375, 0.0459162965, 0.045086991
# 0.000020, 0.016831476249999998, 0.0168619622, 0.0168009903, 0.05048816275, 0.0505775362, 0.0503987893
# 0.000020, 0.016977229150000002, 0.0169781595, 0.0169762988, 0.050927635299999996, 0.0509307757, 0.0509244949
# 0.000020, 0.01711356825, 0.017132828, 0.0170943085, 0.051345048500000004, 0.0514011346, 0.0512889624
# 0.000020, 0.01749450995, 0.0175211672, 0.0174678527, 0.05247812535, 0.052557461, 0.0523987897
# 0.000020, 0.01707489135, 0.0170889292, 0.0170608535, 0.0512162168, 0.0512568057, 0.0511756279
# 0.000020, 0.0121051194, 0.0121672973, 0.0120429415, 0.036267109199999994, 0.0364528373, 0.0360813811
# 0.000020, 0.01797594225, 0.0180224944, 0.0179293901, 0.05388679545, 0.0540246554, 0.0537489355
# 0.000020, 0.01330499865, 0.0133223869, 0.0132876104, 0.039917917950000006, 0.0399691761, 0.0398666598
# 0.000020, 0.0187811004, 0.0188004188, 0.018761782, 0.05632176435, 0.0563783161, 0.0562652126
# 0.000020, 0.01896359675, 0.0189917441, 0.0189354494, 0.056877831000000004, 0.0569605045, 0.0567951575
# 0.000020, 0.0177609045, 0.0177775174, 0.0177442916, 0.05327525365, 0.0533239916, 0.0532265157
# 0.000020, 0.017575703550000002, 0.0176103357, 0.0175410714, 0.052744761099999996, 0.0528453551, 0.0526441671
# 0.000020, 0.0178537145, 0.017870564, 0.017836865, 0.05355715565, 0.0536062047, 0.0535081066
# 0.000020, 0.0183456065, 0.0183567349, 0.0183344781, 0.0550365839, 0.0550707206, 0.0550024472
